# %%
import cv2 as cv

# %% [markdown]
# ## Problem 1

# %%
pct1 = cv.imread('pic1.jpg')
pct2 = cv.imread('pic2.jpg')
pct3 = cv.imread('pic3.jpg')

cv.imshow('Pic1', pct1)
cv.imshow('Pic2', pct2)
cv.imshow('Pic3', pct3)

cv.waitKey(0)
# Out:
# 112

# %% [markdown]
# ## Problem 2

# %%
capture = cv.VideoCapture('vid1.mp4')

while True:
    isTrue, frame = capture.read() 
    
    if isTrue:
        cv.imshow('vid1', frame)
    else:
        print('empty frame')
        exit(1)
    
    if cv.waitKey(20) & 0xFF == ord('d'):
        break

capture.release()
cv.destroyAllWindows()
    
cv.waitKey(0)
# Out:
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# empty frame
# ...

# %% [markdown]
# ## Problem 3

# %%
def rescaleFrame(frame, scale = 0.75):
    width = int(frame.shape[1] * scale)
    height = int(frame.shape[0] * scale)
    dimensions = (width, height)
    
    return cv.resize(frame, dimensions, interpolation=cv.INTER_AREA) #will talk more about this later

# %%
pic1 = cv.imread('pic1.jpg')

pic1_rescaled = rescaleFrame(pic1, 0.5)

cv.imshow('pic1', pic1)
cv.imshow('pic1_rescaled', pic1_rescaled)


cv.waitKey(0)
# Out:
# 100

# %% [markdown]
# ## Problem 4

# %%
def rescaleFrame(frame, scale = 0.75):
    width = int(frame.shape[1] * scale)
    height = int(frame.shape[0] * scale)
    dimensions = (width, height)
    
    return cv.resize(frame, dimensions, interpolation=cv.INTER_AREA)

# %%
capture = cv.VideoCapture('vid1.mp4')

while True:
    isTrue, frame = capture.read() 
    
    if frame is not None: 
        frame_rescaled = rescaleFrame(frame, 0.5)
        cv.imshow('vid1', frame)
        cv.imshow('vid1_rescaled', frame_rescaled)
    else:
        print('empty frame')
        exit(1)
    
    if cv.waitKey(20) & 0xFF == ord('d'):
        break

capture.release()
cv.destroyAllWindows() #distroying all windows since we don't need them anymore
    
cv.waitKey(0)

# %% [markdown]
# ## Problem 5

# %%
pic2 = cv.imread('pic2.jpg')
cv.circle(pic2, (pic2.shape[1]//2, pic2.shape[0]//2), 50, (0, 0, 255), thickness = cv.FILLED)
pic2_original = cv.imread('pic2.jpg')
cv.imshow('pic2', pic2_original)
cv.imshow('pic2_rectangle', pic2)

cv.waitKey(0)
# Out:
# 100

# %% [markdown]
# ## Problem 6

# %%
pic2 = cv.imread('pic2.jpg')

cv.rectangle(pic2, (20,20), (pic2.shape[1]//2, pic2.shape[0]//2), (0,140,255), thickness = 2)
cv.imshow('pic2_rectangle', pic2)

cv.waitKey(0)
# Out:
# 100

# %% [markdown]
# ## Problem 7

# %%
pic1 = cv.imread('pic1.jpg')

cv.line(pic1, (0,0), (pic1.shape[1], pic1.shape[0]), (0, 255, 0), thickness = 3)
cv.imshow('pic1_Line', pic1)

cv.waitKey(0)
# Out:
# 100
